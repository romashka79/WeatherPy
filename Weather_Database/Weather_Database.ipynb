# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | pisco
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | kenda
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 1 | mathathane
# Processing Record 9 of Set 1 | pontes e lacerda
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | portland
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | sioux lookout
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | spencer
# Processing Record 18 of Set 1 | navirai
# Processing Record 19 of Set 1 | marsa matruh
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | presidencia roque saenz pena
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | cururupu
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | ibra
# Processing Record 28 of Set 1 | ishigaki
# Processing Record 29 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 1 | lavrentiya
# Processing Record 31 of Set 1 | atar
# Processing Record 32 of Set 1 | cherskiy
# Processing Record 33 of Set 1 | belyy yar
# Processing Record 34 of Set 1 | egvekinot
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | codrington
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | muravlenko
# Processing Record 42 of Set 1 | xichang
# Processing Record 43 of Set 1 | hirara
# Processing Record 44 of Set 1 | skibbereen
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | teruel
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | san giljan
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | zaysan
# Processing Record 1 of Set 2 | kokkola
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | amapa
# Processing Record 4 of Set 2 | nizhniy tsasuchey
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | xuanzhou
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | kalmar
# Processing Record 9 of Set 2 | chancay
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | kez
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | jogindarnagar
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | kajaani
# Processing Record 16 of Set 2 | necochea
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | sungai padi
# Processing Record 19 of Set 2 | sobolevo
# Processing Record 20 of Set 2 | tayoltita
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | arman
# Processing Record 23 of Set 2 | samarinda
# Processing Record 24 of Set 2 | margate
# Processing Record 25 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 2 | araceli
# Processing Record 27 of Set 2 | rocha
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | mattru
# Processing Record 31 of Set 2 | chumikan
# Processing Record 32 of Set 2 | indianola
# Processing Record 33 of Set 2 | san rafael del sur
# Processing Record 34 of Set 2 | taoudenni
# Processing Record 35 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | shahrud
# Processing Record 39 of Set 2 | busselton
# Processing Record 40 of Set 2 | rawson
# Processing Record 41 of Set 2 | sao filipe
# Processing Record 42 of Set 2 | ambon
# Processing Record 43 of Set 2 | abu zabad
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | christchurch
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 2 | kruisfontein
# Processing Record 49 of Set 2 | hovd
# Processing Record 50 of Set 2 | brae
# Processing Record 1 of Set 3 | quchan
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | dossor
# Processing Record 4 of Set 3 | san vicente
# Processing Record 5 of Set 3 | caravelas
# Processing Record 6 of Set 3 | poum
# Processing Record 7 of Set 3 | shubarshi
# Processing Record 8 of Set 3 | olinda
# Processing Record 9 of Set 3 | tuktoyaktuk
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | mehamn
# Processing Record 12 of Set 3 | half moon bay
# Processing Record 13 of Set 3 | vestmannaeyjar
# Processing Record 14 of Set 3 | tulum
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | atuona
# Processing Record 18 of Set 3 | onguday
# Processing Record 19 of Set 3 | clyde river
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | yuanping
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | kununurra
# Processing Record 26 of Set 3 | tateyama
# Processing Record 27 of Set 3 | butembo
# Processing Record 28 of Set 3 | saint george
# Processing Record 29 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 30 of Set 3 | ambanja
# Processing Record 31 of Set 3 | totness
# Processing Record 32 of Set 3 | ahipara
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | helena
# Processing Record 35 of Set 3 | chenzhou
# Processing Record 36 of Set 3 | khartoum
# Processing Record 37 of Set 3 | campbell river
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | taunggyi
# Processing Record 40 of Set 3 | fort-shevchenko
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | puerto escondido
# Processing Record 43 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | balakirevo
# Processing Record 48 of Set 3 | grosseto
# Processing Record 49 of Set 3 | sibu
# Processing Record 50 of Set 3 | pangnirtung
# Processing Record 1 of Set 4 | minuri
# Processing Record 2 of Set 4 | yulara
# Processing Record 3 of Set 4 | miramar
# Processing Record 4 of Set 4 | singaraja
# Processing Record 5 of Set 4 | avera
# Processing Record 6 of Set 4 | namibe
# Processing Record 7 of Set 4 | marsh harbour
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | nouadhibou
# Processing Record 10 of Set 4 | okhtyrka
# Processing Record 11 of Set 4 | grand forks
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | kirakira
# Processing Record 14 of Set 4 | keti bandar
# Processing Record 15 of Set 4 | olafsvik
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | smolenskoye
# Processing Record 18 of Set 4 | narsaq
# Processing Record 19 of Set 4 | stanghelle
# Processing Record 20 of Set 4 | vestmanna
# Processing Record 21 of Set 4 | at-bashi
# Processing Record 22 of Set 4 | sechura
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | collie
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | honiara
# Processing Record 27 of Set 4 | pangody
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 4 | pokhara
# Processing Record 31 of Set 4 | sotara
# City not found. Skipping...
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | esmeraldas
# Processing Record 34 of Set 4 | la asuncion
# Processing Record 35 of Set 4 | havoysund
# Processing Record 36 of Set 4 | upington
# Processing Record 37 of Set 4 | bonavista
# Processing Record 38 of Set 4 | deputatskiy
# Processing Record 39 of Set 4 | leningradskiy
# Processing Record 40 of Set 4 | dickinson
# Processing Record 41 of Set 4 | namatanai
# Processing Record 42 of Set 4 | homer
# Processing Record 43 of Set 4 | tura
# Processing Record 44 of Set 4 | broken hill
# Processing Record 45 of Set 4 | khatassy
# Processing Record 46 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | sao joao da barra
# Processing Record 49 of Set 4 | kurchum
# Processing Record 50 of Set 4 | sur
# Processing Record 1 of Set 5 | kaeo
# Processing Record 2 of Set 5 | rognan
# Processing Record 3 of Set 5 | dagana
# Processing Record 4 of Set 5 | bengkulu
# Processing Record 5 of Set 5 | matara
# Processing Record 6 of Set 5 | cidreira
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | moree
# Processing Record 9 of Set 5 | beyneu
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | quartucciu
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | genhe
# Processing Record 15 of Set 5 | shimoda
# Processing Record 16 of Set 5 | lagunas
# Processing Record 17 of Set 5 | alyangula
# Processing Record 18 of Set 5 | luganville
# Processing Record 19 of Set 5 | miandrivazo
# Processing Record 20 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 5 | seoul
# Processing Record 22 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 23 of Set 5 | talara
# Processing Record 24 of Set 5 | cabatuan
# Processing Record 25 of Set 5 | touros
# Processing Record 26 of Set 5 | polevskoy
# Processing Record 27 of Set 5 | shuyskoye
# Processing Record 28 of Set 5 | turan
# Processing Record 29 of Set 5 | isangel
# Processing Record 30 of Set 5 | quixada
# Processing Record 31 of Set 5 | ca mau
# Processing Record 32 of Set 5 | mizque
# Processing Record 33 of Set 5 | amga
# Processing Record 34 of Set 5 | shenjiamen
# Processing Record 35 of Set 5 | dawei
# Processing Record 36 of Set 5 | fortuna
# Processing Record 37 of Set 5 | kasongo
# Processing Record 38 of Set 5 | nanga eboko
# Processing Record 39 of Set 5 | wewak
# Processing Record 40 of Set 5 | tomatlan
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | baykit
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | luan
# Processing Record 45 of Set 5 | tuatapere
# Processing Record 46 of Set 5 | bansang
# Processing Record 47 of Set 5 | san quintin
# Processing Record 48 of Set 5 | ajdabiya
# Processing Record 49 of Set 5 | butaritari
# Processing Record 50 of Set 5 | aloleng
# Processing Record 1 of Set 6 | ploemeur
# Processing Record 2 of Set 6 | roald
# Processing Record 3 of Set 6 | huaral
# Processing Record 4 of Set 6 | grand-santi
# Processing Record 5 of Set 6 | fallon
# Processing Record 6 of Set 6 | aviles
# Processing Record 7 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 8 of Set 6 | guhagar
# Processing Record 9 of Set 6 | bocas del toro
# Processing Record 10 of Set 6 | marawi
# Processing Record 11 of Set 6 | henties bay
# Processing Record 12 of Set 6 | soroti
# Processing Record 13 of Set 6 | kaitangata
# Processing Record 14 of Set 6 | praya
# Processing Record 15 of Set 6 | jardim
# Processing Record 16 of Set 6 | meulaboh
# Processing Record 17 of Set 6 | hokitika
# Processing Record 18 of Set 6 | geraldton
# Processing Record 19 of Set 6 | hervey bay
# Processing Record 20 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 6 | krasnoselkup
# Processing Record 22 of Set 6 | kapoeta
# Processing Record 23 of Set 6 | polunochnoye
# Processing Record 24 of Set 6 | luwingu
# Processing Record 25 of Set 6 | college
# Processing Record 26 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 6 | podolinec
# Processing Record 28 of Set 6 | jalu
# Processing Record 29 of Set 6 | berlevag
# Processing Record 30 of Set 6 | dikson
# Processing Record 31 of Set 6 | cattolica
# Processing Record 32 of Set 6 | lorengau
# Processing Record 33 of Set 6 | seymchan
# Processing Record 34 of Set 6 | fairbanks
# Processing Record 35 of Set 6 | los llanos de aridane
# Processing Record 36 of Set 6 | anloga
# Processing Record 37 of Set 6 | khatanga
# Processing Record 38 of Set 6 | morondava
# Processing Record 39 of Set 6 | bethel
# Processing Record 40 of Set 6 | acapulco
# Processing Record 41 of Set 6 | asyut
# Processing Record 42 of Set 6 | husavik
# Processing Record 43 of Set 6 | kargil
# Processing Record 44 of Set 6 | warrnambool
# Processing Record 45 of Set 6 | nigde
# Processing Record 46 of Set 6 | riyadh
# Processing Record 47 of Set 6 | praia
# Processing Record 48 of Set 6 | faanui
# Processing Record 49 of Set 6 | arles
# Processing Record 50 of Set 6 | port macquarie
# Processing Record 1 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | adrasmon
# Processing Record 3 of Set 7 | salalah
# Processing Record 4 of Set 7 | patti
# Processing Record 5 of Set 7 | georgetown
# Processing Record 6 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 7 | saint-joseph
# Processing Record 8 of Set 7 | juxtlahuaca
# Processing Record 9 of Set 7 | pouebo
# Processing Record 10 of Set 7 | tezu
# Processing Record 11 of Set 7 | issoire
# Processing Record 12 of Set 7 | broome
# Processing Record 13 of Set 7 | comodoro rivadavia
# Processing Record 14 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 7 | aswan
# Processing Record 16 of Set 7 | magistralnyy
# Processing Record 17 of Set 7 | samarai
# Processing Record 18 of Set 7 | mahebourg
# Processing Record 19 of Set 7 | hamilton
# Processing Record 20 of Set 7 | bredasdorp
# Processing Record 21 of Set 7 | saint anthony
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | pevek
# Processing Record 24 of Set 7 | north bend
# Processing Record 25 of Set 7 | palmer
# Processing Record 26 of Set 7 | banjar
# Processing Record 27 of Set 7 | quelimane
# Processing Record 28 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 7 | guaratinga
# Processing Record 30 of Set 7 | puerto santander
# Processing Record 31 of Set 7 | jodhpur
# Processing Record 32 of Set 7 | san ramon de la nueva oran
# Processing Record 33 of Set 7 | miranorte
# City not found. Skipping...
# Processing Record 34 of Set 7 | bambous virieux
# Processing Record 35 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 7 | morant bay
# Processing Record 37 of Set 7 | mogadishu
# Processing Record 38 of Set 7 | paltin
# Processing Record 39 of Set 7 | stamsund
# City not found. Skipping...
# Processing Record 40 of Set 7 | wucheng
# Processing Record 41 of Set 7 | safaga
# Processing Record 42 of Set 7 | dingle
# Processing Record 43 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 7 | ostrovnoy
# Processing Record 45 of Set 7 | nyuksenitsa
# Processing Record 46 of Set 7 | garissa
# Processing Record 47 of Set 7 | east london
# Processing Record 48 of Set 7 | rawlins
# Processing Record 49 of Set 7 | lillooet
# Processing Record 50 of Set 7 | deniliquin
# Processing Record 1 of Set 8 | kaupanger
# Processing Record 2 of Set 8 | komsomolskiy
# Processing Record 3 of Set 8 | pital
# Processing Record 4 of Set 8 | tara
# Processing Record 5 of Set 8 | norman wells
# Processing Record 6 of Set 8 | lagoa
# Processing Record 7 of Set 8 | alvorada
# Processing Record 8 of Set 8 | diego de almagro
# Processing Record 9 of Set 8 | slave lake
# Processing Record 10 of Set 8 | duz
# City not found. Skipping...
# Processing Record 11 of Set 8 | kuytun
# Processing Record 12 of Set 8 | nortelandia
# Processing Record 13 of Set 8 | guerrero negro
# Processing Record 14 of Set 8 | grafton
# Processing Record 15 of Set 8 | opunake
# Processing Record 16 of Set 8 | brookings
# Processing Record 17 of Set 8 | tual
# Processing Record 18 of Set 8 | dhidhdhoo
# Processing Record 19 of Set 8 | byron bay
# Processing Record 20 of Set 8 | coahuayana
# Processing Record 21 of Set 8 | kaura namoda
# Processing Record 22 of Set 8 | fare
# Processing Record 23 of Set 8 | srednekolymsk
# Processing Record 24 of Set 8 | port hedland
# Processing Record 25 of Set 8 | gorin
# Processing Record 26 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 8 | tautira
# Processing Record 28 of Set 8 | ulladulla
# Processing Record 29 of Set 8 | yuli
# Processing Record 30 of Set 8 | ystad
# Processing Record 31 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 8 | jiuquan
# Processing Record 33 of Set 8 | viedma
# Processing Record 34 of Set 8 | chute-aux-outardes
# Processing Record 35 of Set 8 | westport
# Processing Record 36 of Set 8 | darhan
# Processing Record 37 of Set 8 | constitucion
# Processing Record 38 of Set 8 | tessalit
# Processing Record 39 of Set 8 | shahr-e kord
# Processing Record 40 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 8 | dongsheng
# Processing Record 42 of Set 8 | brasilia
# Processing Record 43 of Set 8 | natal
# Processing Record 44 of Set 8 | yar-sale
# Processing Record 45 of Set 8 | snyder
# Processing Record 46 of Set 8 | gemona
# Processing Record 47 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 8 | monterey
# Processing Record 49 of Set 8 | springbok
# Processing Record 50 of Set 8 | klaksvik
# Processing Record 1 of Set 9 | hasaki
# Processing Record 2 of Set 9 | anadyr
# Processing Record 3 of Set 9 | port-cartier
# Processing Record 4 of Set 9 | yenagoa
# Processing Record 5 of Set 9 | skelleftea
# Processing Record 6 of Set 9 | itoman
# Processing Record 7 of Set 9 | saldanha
# Processing Record 8 of Set 9 | nouakchott
# Processing Record 9 of Set 9 | challans
# Processing Record 10 of Set 9 | yairipok
# Processing Record 11 of Set 9 | kamina
# Processing Record 12 of Set 9 | beringovskiy
# Processing Record 13 of Set 9 | batagay-alyta
# Processing Record 14 of Set 9 | harihar
# Processing Record 15 of Set 9 | cape elizabeth
# City not found. Skipping...
# Processing Record 16 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 9 | chuzhou
# Processing Record 18 of Set 9 | kenai
# Processing Record 19 of Set 9 | cockburn town
# Processing Record 20 of Set 9 | trairi
# Processing Record 21 of Set 9 | snezhnogorsk
# Processing Record 22 of Set 9 | lakes entrance
# Processing Record 23 of Set 9 | bilibino
# Processing Record 24 of Set 9 | ust-barguzin
# Processing Record 25 of Set 9 | emba
# Processing Record 26 of Set 9 | chapais
# Processing Record 27 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 9 | colares
# Processing Record 29 of Set 9 | fort nelson
# Processing Record 30 of Set 9 | lompoc
# Processing Record 31 of Set 9 | casper
# Processing Record 32 of Set 9 | ust-tsilma
# Processing Record 33 of Set 9 | sokoni
# Processing Record 34 of Set 9 | antofagasta
# Processing Record 35 of Set 9 | korla
# Processing Record 36 of Set 9 | berdigestyakh
# Processing Record 37 of Set 9 | tiznit
# Processing Record 38 of Set 9 | kampot
# Processing Record 39 of Set 9 | labuhan
# Processing Record 40 of Set 9 | wajima
# Processing Record 41 of Set 9 | kant
# Processing Record 42 of Set 9 | dryden
# Processing Record 43 of Set 9 | devonport
# Processing Record 44 of Set 9 | uzumlu
# City not found. Skipping...
# Processing Record 45 of Set 9 | ambulu
# Processing Record 46 of Set 9 | corn island
# Processing Record 47 of Set 9 | hami
# Processing Record 48 of Set 9 | baiyin
# Processing Record 49 of Set 9 | kassala
# Processing Record 50 of Set 9 | vanimo
# Processing Record 1 of Set 10 | carnarvon
# Processing Record 2 of Set 10 | ocos
# Processing Record 3 of Set 10 | touba
# Processing Record 4 of Set 10 | rio claro
# Processing Record 5 of Set 10 | sarakhs
# Processing Record 6 of Set 10 | oranjemund
# Processing Record 7 of Set 10 | merauke
# Processing Record 8 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 9 of Set 10 | troitsko-pechorsk
# Processing Record 10 of Set 10 | lengede
# Processing Record 11 of Set 10 | high rock
# Processing Record 12 of Set 10 | sainte-thecle
# Processing Record 13 of Set 10 | tabou
# Processing Record 14 of Set 10 | gouyave
# Processing Record 15 of Set 10 | xifeng
# Processing Record 16 of Set 10 | dudinka
# Processing Record 17 of Set 10 | sangar
# Processing Record 18 of Set 10 | innisfail
# Processing Record 19 of Set 10 | lesozavodsk
# Processing Record 20 of Set 10 | filingue
# Processing Record 21 of Set 10 | sydney
# Processing Record 22 of Set 10 | qujing
# Processing Record 23 of Set 10 | tondano
# Processing Record 24 of Set 10 | tecpan
# Processing Record 25 of Set 10 | cajamarca
# Processing Record 26 of Set 10 | richards bay
# Processing Record 27 of Set 10 | fiumicino
# Processing Record 28 of Set 10 | general roca
# Processing Record 29 of Set 10 | kamaishi
# Processing Record 30 of Set 10 | pochutla
# Processing Record 31 of Set 10 | porto novo
# Processing Record 32 of Set 10 | fengkou
# Processing Record 33 of Set 10 | vidalia
# Processing Record 34 of Set 10 | guane
# Processing Record 35 of Set 10 | awjilah
# Processing Record 36 of Set 10 | yumen
# Processing Record 37 of Set 10 | ixtapa
# Processing Record 38 of Set 10 | port hardy
# Processing Record 39 of Set 10 | eruwa
# Processing Record 40 of Set 10 | ashington
# Processing Record 41 of Set 10 | houston
# Processing Record 42 of Set 10 | rio gallegos
# Processing Record 43 of Set 10 | san patricio
# Processing Record 44 of Set 10 | guarapuava
# Processing Record 45 of Set 10 | ketchikan
# Processing Record 46 of Set 10 | whyalla
# Processing Record 47 of Set 10 | tigil
# Processing Record 48 of Set 10 | kainantu
# Processing Record 49 of Set 10 | hofn
# Processing Record 50 of Set 10 | george
# Processing Record 1 of Set 11 | tombouctou
# Processing Record 2 of Set 11 | te anau
# Processing Record 3 of Set 11 | turinskaya sloboda
# Processing Record 4 of Set 11 | lujiang
# Processing Record 5 of Set 11 | yasothon
# Processing Record 6 of Set 11 | kahului
# Processing Record 7 of Set 11 | huilong
# Processing Record 8 of Set 11 | taga dzong
# City not found. Skipping...
# Processing Record 9 of Set 11 | qaqortoq
# Processing Record 10 of Set 11 | bolpur
# Processing Record 11 of Set 11 | opuwo
# Processing Record 12 of Set 11 | cap malheureux
# Processing Record 13 of Set 11 | puerto carreno
# Processing Record 14 of Set 11 | zahirabad
# Processing Record 15 of Set 11 | nelson bay
# Processing Record 16 of Set 11 | grand gaube
# Processing Record 17 of Set 11 | acajutla
# Processing Record 18 of Set 11 | lata
# Processing Record 19 of Set 11 | hambantota
# Processing Record 20 of Set 11 | senador pompeu
# Processing Record 21 of Set 11 | new richmond
# Processing Record 22 of Set 11 | galle
# Processing Record 23 of Set 11 | muroto
# Processing Record 24 of Set 11 | kano
# Processing Record 25 of Set 11 | thinadhoo
# Processing Record 26 of Set 11 | omsukchan
# Processing Record 27 of Set 11 | saravan
# Processing Record 28 of Set 11 | esso
# Processing Record 29 of Set 11 | mashhad
# Processing Record 30 of Set 11 | goundam
# Processing Record 31 of Set 11 | muros
# Processing Record 32 of Set 11 | hualmay
# Processing Record 33 of Set 11 | aksu
# Processing Record 34 of Set 11 | atka
# City not found. Skipping...
# Processing Record 35 of Set 11 | moroni
# Processing Record 36 of Set 11 | qurbah
# City not found. Skipping...
# Processing Record 37 of Set 11 | dalbandin
# Processing Record 38 of Set 11 | san luis
# Processing Record 39 of Set 11 | port augusta
# Processing Record 40 of Set 11 | mount gambier
# Processing Record 41 of Set 11 | pyaozerskiy
# Processing Record 42 of Set 11 | biryusinsk
# Processing Record 43 of Set 11 | kalmunai
# Processing Record 44 of Set 11 | nanortalik
# Processing Record 45 of Set 11 | vallenar
# Processing Record 46 of Set 11 | dordrecht
# Processing Record 47 of Set 11 | karratha
# Processing Record 48 of Set 11 | agadir
# Processing Record 49 of Set 11 | marzuq
# Processing Record 50 of Set 11 | mount isa
# Processing Record 1 of Set 12 | san policarpo
# Processing Record 2 of Set 12 | a
# City not found. Skipping...
# Processing Record 3 of Set 12 | honningsvag
# Processing Record 4 of Set 12 | kosh-agach
# Processing Record 5 of Set 12 | sosnovo-ozerskoye
# Processing Record 6 of Set 12 | buta
# Processing Record 7 of Set 12 | kingaroy
# Processing Record 8 of Set 12 | chepen
# Processing Record 9 of Set 12 | cartagena del chaira
# Processing Record 10 of Set 12 | neijiang
# Processing Record 11 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 12 | usak
# Processing Record 13 of Set 12 | russell
# Processing Record 14 of Set 12 | miri
# Processing Record 15 of Set 12 | harindanga
# Processing Record 16 of Set 12 | adra
# Processing Record 17 of Set 12 | murray bridge
# Processing Record 18 of Set 12 | rizhao
# Processing Record 19 of Set 12 | alofi
# Processing Record 20 of Set 12 | healesville
# Processing Record 21 of Set 12 | nome
# Processing Record 22 of Set 12 | flinders
# Processing Record 23 of Set 12 | sovetskaya gavan
# Processing Record 24 of Set 12 | uglich
# Processing Record 25 of Set 12 | skiathos
# Processing Record 26 of Set 12 | grindavik
# Processing Record 27 of Set 12 | mayumba
# Processing Record 28 of Set 12 | saint-pierre
# Processing Record 29 of Set 12 | hay river
# Processing Record 30 of Set 12 | aklavik
# Processing Record 31 of Set 12 | padang
# Processing Record 32 of Set 12 | eureka
# Processing Record 33 of Set 12 | tongliao
# Processing Record 34 of Set 12 | sept-iles
# Processing Record 35 of Set 12 | bucerias
# Processing Record 36 of Set 12 | dunedin
# Processing Record 37 of Set 12 | kamenka
# Processing Record 38 of Set 12 | itarema
# Processing Record 39 of Set 12 | zhigansk
# Processing Record 40 of Set 12 | kralendijk
# Processing Record 41 of Set 12 | harper
# Processing Record 42 of Set 12 | turayf
# Processing Record 43 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 44 of Set 12 | bandarbeyla
# Processing Record 45 of Set 12 | victoria
# Processing Record 46 of Set 12 | virginia beach
# Processing Record 47 of Set 12 | tromso
# Processing Record 48 of Set 12 | kloulklubed
# Processing Record 49 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 12 | karaton
# Processing Record 1 of Set 13 | souillac
# Processing Record 2 of Set 13 | suvorovo
# Processing Record 3 of Set 13 | nyurba
# Processing Record 4 of Set 13 | thilogne
# City not found. Skipping...
# Processing Record 5 of Set 13 | dolores
# Processing Record 6 of Set 13 | preeceville
# Processing Record 7 of Set 13 | wick
# Processing Record 8 of Set 13 | lebyazhye
# Processing Record 9 of Set 13 | elizabeth city
# Processing Record 10 of Set 13 | ancud
# Processing Record 11 of Set 13 | erzurum
# Processing Record 12 of Set 13 | ilinskiy
# Processing Record 13 of Set 13 | moerai
# Processing Record 14 of Set 13 | mullingar
# Processing Record 15 of Set 13 | fereydun kenar
# Processing Record 16 of Set 13 | gorontalo
# Processing Record 17 of Set 13 | santa maria
# Processing Record 18 of Set 13 | waingapu
# Processing Record 19 of Set 13 | imbituba
# Processing Record 20 of Set 13 | cocobeach
# Processing Record 21 of Set 13 | zhengjiatun
# Processing Record 22 of Set 13 | quatre cocos
# Processing Record 23 of Set 13 | bara
# Processing Record 24 of Set 13 | glace bay
# Processing Record 25 of Set 13 | bozeman
# Processing Record 26 of Set 13 | emporia
# Processing Record 27 of Set 13 | high level
# Processing Record 28 of Set 13 | karlivka
# Processing Record 29 of Set 13 | tias
# Processing Record 30 of Set 13 | kodinsk
# Processing Record 31 of Set 13 | canaries
# Processing Record 32 of Set 13 | el alto
# Processing Record 33 of Set 13 | santiago del estero
# Processing Record 34 of Set 13 | burdeos
# Processing Record 35 of Set 13 | mitu
# Processing Record 36 of Set 13 | biloli
# Processing Record 37 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of Set 13 | fort madison
# Processing Record 40 of Set 13 | szabadszallas
# Processing Record 41 of Set 13 | bereda
# Processing Record 42 of Set 13 | ivybridge
# Processing Record 43 of Set 13 | adrar
# Processing Record 44 of Set 13 | san angelo
# Processing Record 45 of Set 13 | bilma
# Processing Record 46 of Set 13 | qui nhon
# Processing Record 47 of Set 13 | beohari
# Processing Record 48 of Set 13 | asau
# Processing Record 49 of Set 13 | limbang
# Processing Record 50 of Set 13 | hangu
# Processing Record 1 of Set 14 | buala
# Processing Record 2 of Set 14 | khuzhir
# Processing Record 3 of Set 14 | sinnamary
# Processing Record 4 of Set 14 | ye
# City not found. Skipping...
# Processing Record 5 of Set 14 | kyren
# Processing Record 6 of Set 14 | dekernes
# Processing Record 7 of Set 14 | acton vale
# Processing Record 8 of Set 14 | haines junction
# Processing Record 9 of Set 14 | floro
# Processing Record 10 of Set 14 | villa carlos paz
# Processing Record 11 of Set 14 | zhaocheng
# City not found. Skipping...
# Processing Record 12 of Set 14 | ayame
# Processing Record 13 of Set 14 | gayeri
# Processing Record 14 of Set 14 | corinth
# Processing Record 15 of Set 14 | yamada
# Processing Record 16 of Set 14 | cayenne
# Processing Record 17 of Set 14 | bartica
# Processing Record 18 of Set 14 | aasiaat
# Processing Record 19 of Set 14 | kasongo-lunda
# Processing Record 20 of Set 14 | anda
# Processing Record 21 of Set 14 | tinyahuarco
# Processing Record 22 of Set 14 | kinablangan
# Processing Record 23 of Set 14 | novosheshminsk
# Processing Record 24 of Set 14 | zheleznodorozhnyy
# Processing Record 25 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 14 | bathsheba
# Processing Record 27 of Set 14 | la ronge
# Processing Record 28 of Set 14 | chernyshevskiy
# Processing Record 29 of Set 14 | talnakh
# Processing Record 30 of Set 14 | moose factory
# Processing Record 31 of Set 14 | hopelchen
# Processing Record 32 of Set 14 | konya
# Processing Record 33 of Set 14 | ngerengere
# Processing Record 34 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 14 | vanderhoof
# Processing Record 36 of Set 14 | pandan
# Processing Record 37 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 38 of Set 14 | obluche
# City not found. Skipping...
# Processing Record 39 of Set 14 | port townsend
# Processing Record 40 of Set 14 | san isidro
# Processing Record 41 of Set 14 | jiexiu
# Processing Record 42 of Set 14 | new albany
# Processing Record 43 of Set 14 | hammerfest
# Processing Record 44 of Set 14 | laredo
# Processing Record 45 of Set 14 | agapovka
# Processing Record 46 of Set 14 | methoni
# Processing Record 47 of Set 14 | havelock
# Processing Record 48 of Set 14 | saint-augustin
# Processing Record 49 of Set 14 | frankfort
# Processing Record 50 of Set 14 | inirida
# Processing Record 1 of Set 15 | srandakan
# Processing Record 2 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 15 | paamiut
# Processing Record 4 of Set 15 | wanganui
# Processing Record 5 of Set 15 | zhigalovo
# Processing Record 6 of Set 15 | am timan
# Processing Record 7 of Set 15 | bonfim
# Processing Record 8 of Set 15 | leopold
# Processing Record 9 of Set 15 | bairiki
# Processing Record 10 of Set 15 | dawson creek
# Processing Record 11 of Set 15 | lahaina
# Processing Record 12 of Set 15 | ponta delgada
# Processing Record 13 of Set 15 | xingyi
# Processing Record 14 of Set 15 | nhulunbuy
# Processing Record 15 of Set 15 | yaan
# Processing Record 16 of Set 15 | mackay
# Processing Record 17 of Set 15 | lubana
# Processing Record 18 of Set 15 | saint-georges
# Processing Record 19 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 15 | chiang rai
# Processing Record 21 of Set 15 | alice springs
# Processing Record 22 of Set 15 | norden
# Processing Record 23 of Set 15 | nijar
# Processing Record 24 of Set 15 | urumqi
# Processing Record 25 of Set 15 | abu kamal
# Processing Record 26 of Set 15 | praia da vitoria
# Processing Record 27 of Set 15 | shahreza
# Processing Record 28 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 15 | kyra
# Processing Record 30 of Set 15 | vyartsilya
# Processing Record 31 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 32 of Set 15 | walvis bay
# Processing Record 33 of Set 15 | ashqelon
# Processing Record 34 of Set 15 | toora-khem
# Processing Record 35 of Set 15 | jijiga
# Processing Record 36 of Set 15 | batagay
# Processing Record 37 of Set 15 | parati
# Processing Record 38 of Set 15 | taltal
# Processing Record 39 of Set 15 | miranda de ebro
# Processing Record 40 of Set 15 | laguna
# Processing Record 41 of Set 15 | kyaiklat
# Processing Record 42 of Set 15 | lydenburg
# Processing Record 43 of Set 15 | vilhena
# Processing Record 44 of Set 15 | luohe
# Processing Record 45 of Set 15 | letpadan
# Processing Record 46 of Set 15 | hobyo
# Processing Record 47 of Set 15 | trinidad
# Processing Record 48 of Set 15 | victoria point
# Processing Record 49 of Set 15 | san pedro
# Processing Record 50 of Set 15 | nantucket
# Processing Record 1 of Set 16 | beloha
# Processing Record 2 of Set 16 | umea
# Processing Record 3 of Set 16 | rorvik
# Processing Record 4 of Set 16 | belaya gora
# Processing Record 5 of Set 16 | garowe
# Processing Record 6 of Set 16 | najran
# Processing Record 7 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 16 | aguimes
# Processing Record 9 of Set 16 | linxia
# Processing Record 10 of Set 16 | griffith
# Processing Record 11 of Set 16 | lisakovsk
# Processing Record 12 of Set 16 | aitape
# Processing Record 13 of Set 16 | klyuchi
# Processing Record 14 of Set 16 | cherdyn
# Processing Record 15 of Set 16 | boa vista
# Processing Record 16 of Set 16 | lumut
# Processing Record 17 of Set 16 | tucupita
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 705

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hobart      AU -42.8794  147.3294     58.23        79
# 1            Castro      BR -24.7911  -50.0119     59.76        90
# 2             Pisco      PE -13.7000  -76.2167     61.02        82
# 3            Barrow      US  71.2906 -156.7887     41.02        93
# 4             Kenda      IN  23.2000   86.5333     79.07        84
# 5         Jamestown      US  42.0970  -79.2353     78.44        47
# 6        Mathathane      BW -22.2687   28.7495     55.33        79
# 7  Pontes E Lacerda      BR -15.2261  -59.3353     72.63        56
# 8           Rikitea      PF -23.1203 -134.9692     75.33        77
# 9          Portland      US  45.5234 -122.6762     80.62        56
#
#    Cloudiness  Wind Speed Current Description
# 0          75        5.75       moderate rain
# 1           0        4.72           clear sky
# 2         100       12.66     overcast clouds
# 3         100       13.80     overcast clouds
# 4          74        5.10       broken clouds
# 5           0       10.36           clear sky
# 6           1        8.97           clear sky
# 7          57        3.02       broken clouds
# 8          50       16.87          light rain
# 9          20       11.50          few clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
